# %%
fruits = ["apple","banana","cherry"]
for x in  fruits:
    print (x)
    if x == "banana":
        break
# Out:
# apple
# banana

# %%
fruits = ["apple","banana","cherry"]
for fruit in fruits:
    if fruit == "banana":
        break
    print(fruit)
# Out:
# apple

# %%
fruits = ["cherry","banana","apple"]
for fruit in fruits:
    print(fruit)
    if fruit =="banana":
        continue
# Out:
# cherry
# banana
# apple

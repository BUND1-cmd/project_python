# %%
fruits = ["apple","banana","cherry"]
for x in  fruits:
    print (x)
    if x == "banana":
        break
# Out:
# apple
# banana

# %%
fruits = ["apple","banana","cherry"]
for fruit in fruits:
    if fruit == "banana":
        break
    print(fruit)
# Out:
# apple

# %%
fruits = ["cherry","banana","apple"]
for fruit in fruits:
    print(fruit)
    if fruit =="banana":
        continue
# Out:
# cherry
# banana
# apple

# %%
for x in range (6):
    print (x)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5

# %%
for x in range (2,6):
    print (x)
# Out:
# 2
# 3
# 4
# 5

# %%
for x in range(2,30,3):
    print(x)
# Out:
# 2
# 5
# 8
# 11
# 14
# 17
# 20
# 23
# 26
# 29

# %%
for x in range(6):
    print(x)
else:
    print("finally finished!")
# Out:
# 0
# 1
# 2
# 3
# 4
# 5
# finally finished!

# %%
for x in range(6):
    if x == 3:
        break
    print(x)
else:
    print("finally finished")
# Out:
# 0
# 1
# 2

# %%
adj =["red","big","tasty"]
fruits = ["apple","banana","cherry"]
for x in adj:
    for y in fruits:
        print(x,y)
# Out:
# red apple
# red banana
# red cherry
# big apple
# big banana
# big cherry
# tasty apple
# tasty banana
# tasty cherry

# %%
for x in [1,2,3,4]:
    pass

# %%
def my_function():
    print("hello my function")
my_function()
# Out:
# hello my function

# %%
def farhenheit_to_celcius (farhenheit):
    return (farhenheit-32)* 5/9
print(farhenheit_to_celcius(56))
# Out:
# 13.333333333333334

# %%
def get_greeting():
    return "hello bundi"
message = get_greeting()
print(message)
# Out:
# hello bundi

# %%
f = open("myfile.txt")

# %%
f.close()

import os
os.remove("myfile.txt")
